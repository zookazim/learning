# %%
import json
import re

# %%
# read the JSON file
with open('c2_rmhs_nb_validate_submitted_data.json', 'r') as file:
    data = json.load(file)

# %%
json_string = json.dumps(data)

# %%
# given the string json_string, find all occurrences of the string "execution_count:" and return the number that follows it
rex1 = re.compile(r'"execution_count"\s*:\s*\d+')

# find all occurrences of the string "spark.autotune.trackingId" and return the string that follows it
rex2 = re.compile(r'"spark\.autotune\.trackingId"\s*:\s*"([^"]+)"')

# %%
find_str = rex2.findall(json_string)

# %%
print(find_str)
# Out:
# ['c6e5e9af-5ec5-407a-899d-f3cb346a5c62']

# %%
updated_text = re.sub(r'"spark\.autotune\.trackingId"\s*',"", json_string, flags=re.MULTILINE)

# %%
updated_text = re.sub(r'("execution_count"\s*:\s*)\d+', r'\g<1>0', json_string)

# %%
print(updated_text)
# Out:
# {"name": "c2_rmhs_nb_validate_submitted_data", "properties": {"description": "Ensure a csv file has a header row and if not insert one", "folder": {"name": "c2_rmhs"}, "nbformat": 4, "nbformat_minor": 2, "bigDataPool": {"referenceName": "synsppool1", "type": "BigDataPoolReference"}, "sessionProperties": {"driverMemory": "28g", "driverCores": 4, "executorMemory": "28g", "executorCores": 4, "numExecutors": 2, "runAsWorkspaceSystemIdentity": false, "conf": {"spark.dynamicAllocation.enabled": "false", "spark.dynamicAllocation.minExecutors": "2", "spark.dynamicAllocation.maxExecutors": "2", : "c6e5e9af-5ec5-407a-899d-f3cb346a5c62"}}, "metadata": {"saveOutput": false, "enableDebugMode": false, "kernelspec": {"name": "synapse_pyspark", "display_name": "Synapse PySpark"}, "language_info": {"name": "python"}, "a365ComputeOptions": {"id": "/subscriptions/64b96407-6243-4e44-9932-e2d6c43504bd/resourceGroups/wah-mhcb-n-aze-rg-dlz1/providers/Microsoft.Synapse/workspaces/wah-mhcb-d-aze-syn/bigDataP
# ...

# %%
find_str = rex2.findall(updated_text)
print(find_str)
# Out:
# []

# %%
# save updated JSON string to a new file
with open('c2_rmhs_nb_validate_submitted_data_updated.json', 'w') as file:
    file.write(updated_text)

# %% [markdown]
# ## Different approach

# %%
with open('c2_rmhs_nb_validate_submitted_data.json', 'r', encoding='utf-8') as f:
    json_code = json.load(f)

# %%
for cell in notebook.get("cells", []):
    metadata = cell.get("metadata", {})
    if "spark.autotune.trackingId" in metadata:
        print(f"Removing spark.autotune.trackingId from a cell")
        metadata.pop("spark.autotune.trackingId")
    #cell["metadata"] = metadata

    #cell["execution_count"] = None

# %%
if "metadata" in json_code:
    print(json_code["spark.autotune.trackingId"])

# %%
json_code
# Out:
# {'name': 'c2_rmhs_nb_validate_submitted_data',
#  'properties': {'description': 'Ensure a csv file has a header row and if not insert one',
#   'folder': {'name': 'c2_rmhs'},
#   'nbformat': 4,
#   'nbformat_minor': 2,
#   'bigDataPool': {'referenceName': 'synsppool1',
#    'type': 'BigDataPoolReference'},
#   'sessionProperties': {'driverMemory': '28g',
#    'driverCores': 4,
#    'executorMemory': '28g',
#    'executorCores': 4,
#    'numExecutors': 2,
#    'runAsWorkspaceSystemIdentity': False,
#    'conf': {'spark.dynamicAllocation.enabled': 'false',
#     'spark.dynamicAllocation.minExecutors': '2',
#     'spark.dynamicAllocation.maxExecutors': '2',
#     'spark.autotune.trackingId': 'c6e5e9af-5ec5-407a-899d-f3cb346a5c62'}},
#   'metadata': {'saveOutput': False,
#    'enableDebugMode': False,
#    'kernelspec': {'name': 'synapse_pyspark',
#     'display_name': 'Synapse PySpark'},
#    'language_info': {'name': 'python'},
# ...

# %% [markdown]
# ## Still another approach

# %%
def find_key_recursive(obj, target_key, lstResult):
    if isinstance(obj, dict):
        if target_key in obj:
            return obj[target_key]
        for value in obj.values():
            result = find_key_recursive(value, target_key,lstResult)
            if result is not None:
                lstResult.append(result)
    elif isinstance(obj, list):
        for item in obj:
            result = find_key_recursive(item, target_key,lstResult)
            if result is not None:
                lstResult.append(result)

# %%
with open('c2_rmhs_nb_validate_submitted_data.json', 'r', encoding='utf-8') as f:
    json_code = json.load(f)

lstResult = []

find_attribute = "execution_count"

find_key_recursive(json_code,find_attribute,lstResult)

print(f"Searching for '{find_attribute}' in the JSON code...")
for result in lstResult:
    print(f"Found: {result}")
# Out:
# Searching for 'execution_count' in the JSON code...
# Found: 63
# Found: 64
# Found: 65
# Found: 66
# Found: 67
# Found: 68
# Found: 69
# Found: 70
# Found: 71
# Found: 72
# Found: 73
# Found: 74
# Found: 75
# Found: 76
# Found: 77
# Found: 78
# Found: 79
# Found: 80
# Found: 81
# Found: 82
# Found: 83
# Found: 84
# Found: 85
# Found: 86
# Found: 87
# Found: 88
# Found: 89
# Found: 90
# Found: 91
# Found: 92
# Found: 93
